# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow import keras
import csv
tf.config.run_functions_eagerly(True)

# %%
def get_model_list(f, delim="<|>"):
    with open(f,'r',encoding='utf-8') as f:
        d={}
        while True:
            try:
                line = f.readline()
                line = str(line).split(delim)
                d[str(line[0])]=int(str(line[1]).replace('\n',''))
            except:
                break
    f.close()
    return d

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w,p) for w,p in zip(s["Token"].values.tolist(),
                                                           s["POS"].values.tolist())]
        
        self.grouped = self.data.groupby("Record Number").apply(agg_func)
        self.sentences = [s for s in self.grouped]

# %%
model = keras.models.load_model("./model/model_2.3",compile=False)

# %%
#coded embedding indexing
word2idx = get_model_list("train_words.txt")
pos2idx = get_model_list("pos_tags.txt")
tag2idx = get_model_list("bio_tags.txt")
char2idx = get_model_list("train_chars.txt")

# %%
idx2tag = {i: w for w, i in tag2idx.items()}
idx2word = {i: w for w, i in word2idx.items()}
idx2char = {i: w for w, i in char2idx.items()}

# %%
df = pd.read_csv('data/qdf.csv')

# %%
df
# Out:
#         Record Number                                              Title  \
# 0                   1           SALE ! Kamen Rider Gaim Belt Set No. 802
# 1                   1           SALE ! Kamen Rider Gaim Belt Set No. 802
# 2                   1           SALE ! Kamen Rider Gaim Belt Set No. 802
# 3                   1           SALE ! Kamen Rider Gaim Belt Set No. 802
# 4                   1           SALE ! Kamen Rider Gaim Belt Set No. 802
# ...               ...                                                ...
# 257523          25000  BELLA TAYLOR PATCHWORK QUILTED BLAKELY SMALL /...
# 257524          25000  BELLA TAYLOR PATCHWORK QUILTED BLAKELY SMALL /...
# 257525          25000  BELLA TAYLOR PATCHWORK QUILTED BLAKELY SMALL /...
# 257526          25000  BELLA TAYLOR PATCHWORK QUILTED BLAKELY SMALL /...
# 257527          25000  BELLA TAYLOR PATCHWORK QUILTED BLAKELY SMALL /...
#
#             Token  POS
# 0            SALE   NN
# 1               !    .
# 2           Kamen  NNP
# 3           Rider  NNP
# 4            Gaim  NNP
# ...           ...  ...
# 257523     MEDIUM  NNP
# 257524    HANDBAG  NNP
# 257525      PURSE  NNP
# 257526          ~  NNP
# 257527  IRONSTONE  NNP
#
# [257528 rows x 4 columns]

# %%
getter=SentenceGetter(df)

# %%
sentences = getter.sentences

# %%
max_len=128
max_len_char=128

# %%
X_word = [[word2idx[w[0]] if w[0] in word2idx.keys() else '1' for w in s] for s in sentences]
X_word = pad_sequences(maxlen=max_len, sequences=X_word, value=word2idx["PAD"], padding='post', truncating='post')

# %%
X_pos = [[pos2idx[w[1]] if w[1] in pos2idx.keys() else '0' for w in s] for s in sentences]
X_pos = pad_sequences(maxlen=max_len, sequences=X_pos, value=pos2idx["PAD"], padding='post', truncating='post')

# %%
char2idx[str(sentences[0][1][0])]
# Out:
# 79

# %%
X_char = []
for sentence in sentences:
    sent_seq = []
    for i in range(max_len):
        word_seq = []
        for j in range(max_len_char):
            try:
                word_seq.append(char2idx.get(sentence[i][0][j]))
            except:
                if i>=len(sentence):
                    word_seq.append(char2idx["PAD"])
                elif j>=len(str(sentence[i][0])):
                    word_seq.append(char2idx["PAD"])
                else:
                    t = str(sentences[i][0])
                    if not t[j] in char2idx.keys():
                        word_seq.append(char2idx["UNK"])
                    else:
                        word_seq.append(char2idx['PAD'])
                    
        sent_seq.append(word_seq)
    X_char.append(np.array(sent_seq))
XX_char = np.asarray(X_char).astype("float")
XX_char = np.where(XX_char==None, 1, XX_char)

# %%
XX_char = np.where(XX_char>=129,1,XX_char)

# %%
np.save("X_word_2.3.npy",X_word)
np.save("X_pos_2.3.npy",X_pos)
np.save("XX_char_2.3.npy",XX_char)

# %%
print("___Model Inputs___\n")
[print(i.shape, i.dtype) for i in model.inputs]
print("___Model Outputs___\n")
[print(o.shape, o.dtype) for o in model.outputs]
print("___Model Layers___\n")
[print(l.name, l.input_shape, l.dtype) for l in model.layers]
print("___Data Inputs___\n")
print(X_word.shape)
print(X_pos.shape)
print(XX_char.shape)
# Out:
# ___Model Inputs___
#
# (None, 128) <dtype: 'float32'>
# (None, 128) <dtype: 'float32'>
# (None, 128, 128) <dtype: 'float32'>
# ___Model Outputs___
#
# (None, 128, 115) <dtype: 'float32'>
# ___Model Layers___
#
# Char_Inputs [(None, 128, 128)] float32
# Word_Inputs [(None, 128)] float32
# POS_Inputs [(None, 128)] float32
# Char_Time_Dist (None, 128, 128) float32
# Word_Embed (None, 128) float32
# POS_Embed (None, 128) float32
# Char_LSTM_Enc (None, 128, 128, 32) float32
# Main_Input [(None, 128, 64), (None, 128, 32), (None, 128, 32)] float32
# Main_Dropout (None, 128, 128) float32
# bidirectional_4 (None, 128, 128) float32
# bidirectional_5 (None, 128, 1024) float32
# add_2 [(None, 128, 1024), (None, 128, 1024)] float32
# time_distributed_2 (None, 128, 1024) float32
# ___Data Inputs___
#
# (25000, 128)
# (25000, 128)
# (25000, 128, 128)

# %%
pred_input = [X_word, X_pos, XX_char]

# %%
# y_pred = model.predict([X_word, X_pos, XX_char])
y_pred = model.predict(pred_input)
# Out:
# 782/782 [==============================] - 10851s 14s/step

# %%
np.save("y_pred2.3.npy",y_pred)

# %%
pred_data = np.load("y_pred2.3.npy")

# %%
#unpack predictions into list for dataframe
idx=5001
preds=[]
for x in range(0,len(pred_data)):
    p = np.argmax(pred_data[x],axis=-1)

listvals=[[],[],[]]
for x in range(0,len(pred_data)):
    p = np.argmax(pred_data[x], axis=-1)
    
    for w, pred in zip(X_word[x], p):
        if w!=0:
            if idx2tag[pred]!="No Tag":
                listvals[0].append(idx)
                listvals[1].append(idx2tag[pred])
                listvals[2].append(idx2word[w])

    idx+=1

# %%
def parse_tags(df):
    tag_col = df.columns.get_loc("Aspect Name") 
    tkn_col = df.columns.get_loc("Aspect Value") 
    noparse=['Material', 'Type', 'Size', 'Fabric Type', 'Features','None','Occasion','Obscure']
    
    for x in range(0, len(df)-1):

        if df.iat[x,tag_col]!=None and df.iat[x,tag_col]!="None" and df.iat[x,tkn_col]!=None:
            cur_tag = str(df.iat[x,tag_col])
            
            if cur_tag[:2]=="B-" or cur_tag[:2]=="I-":
                if not cur_tag[2:] in noparse:
                    cur_tkn = str(df.iat[x,tkn_col])
                    y = 1
                    while True:
                        if x+y < len(df):
                            next_tag = str(df.iat[x+y,tag_col])
                            if next_tag[2:]==cur_tag[2:]:
                                if next_tag[:2]=="I-":
                                    cur_tkn = cur_tkn + " " + str(df.iat[x+y,tkn_col])
                                    df.iat[x+y,tkn_col]=None
                                    df.iat[x+y,tag_col]=None
                                elif next_tag[:2]=="E-":
                                    cur_tkn = cur_tkn + " " + str(df.iat[x+y,tkn_col])
                                    df.iat[x,tkn_col]=cur_tkn
                                    df.iat[x,tag_col]=cur_tag[2:]
                                    df.iat[x+y,tkn_col]=None
                                    df.iat[x+y,tag_col]=None
                                    break
                                else:
                                    df.iat[x,tkn_col]=cur_tkn
                                    df.iat[x,tag_col]=cur_tag[2:]
                                    break
                            else:
                                df.iat[x,tkn_col]=cur_tkn
                                df.iat[x,tag_col]=cur_tag[2:]
                                break
                        else:
                            df.iat[x,tkn_col]=cur_tkn
                            df.iat[x,tag_col]=cur_tag[2:]
                            break
                        y+=1
                else:
                    df.iat[x,tag_col]=cur_tag[2:]

            elif cur_tag[:2]=="E-":
                if cur_tag[2:] not in noparse:
                    if str(df.iat[x-1,tag_col])==cur_tag[2:]:
                        df.iat[x,tkn_col]=str(df.iat[x-1,tkn_col])+" "+str(df.iat[x,tkn_col])
                        df.iat[x,tag_col]=cur_tag[2:]
                        df.iat[x-1,tkn_col]=None
                        df.iat[x-1,tag_col]=None
                    else:
                        df.iat[x,tag_col]=cur_tag[2:]
                else:
                    df.iat[x,tag_col]=cur_tag[2:]
            
    df = df[df['Aspect Value']!="None"]            
    df = df.dropna()

# %%
pred_df = pd.DataFrame({"Record Number":listvals[0],"Aspect Name":listvals[1],"Aspect Value":listvals[2]})

# %%
pred_df[pred_df['Record Number']==5015]
# Out:
#      Record Number Aspect Name Aspect Value
# 108           5015       Theme       Rutoto
# 109           5015     B-Theme      ROOTOTE
# 110           5015     E-Theme       Rutoto
# 111           5015        Type         tote
# 112           5015        Type          bag
# 113           5015       Theme         deli
# 114           5015     E-Theme      smaller
# 115           5015  Department       ladies
# 116           5015     B-Theme       simple
# 117           5015     E-Theme        natur

# %%
parse_tags(pred_df)
pred_df = pred_df.dropna()

# %%
len(pred_df)
# Out:
# 172244

# %%
pred_df[100:150]
# Out:
#      Record Number  Aspect Name      Aspect Value
# 108           5015        Theme            Rutoto
# 109           5015        Theme    ROOTOTE Rutoto
# 111           5015         Type              tote
# 112           5015         Type               bag
# 114           5015        Theme      deli smaller
# 115           5015   Department            ladies
# 116           5015        Theme      simple natur
# 118           5016        Model              Love
# 119           5016        Brand          Moschino
# 120           5016        Color             Black
# 121           5016  Fabric Type            Canvas
# 122           5016      Accents  Logo Embroidered
# 124           5016         Type          Shopping
# 125           5016         Type              Tote
# 126           5017        Brand      stone and co
# 129           5017         Type          handbags
# 130           5018   Department            Ladies
# 131           5018      Pattern              Avon
# 132           5018      Pattern         Signature
# 133           5018        Color             Black
# 134           5018         Type               Bag
# 135           5019   Department            Ladies
# 136           5019         Type           Handbag
# 137           5020   Department            Womens
# 138           5020      Accents       Transparent
# 139           5020        Color             Clear
# 140           5020         Type              Tote
# 141           5020     Material             Jelly
# 142           5020         Type           Handbag
# 143           5020       Season            Summer
# 144           5020     Occasion             Beach
# 145           5020         Type               Bag
# 146           5020   Department              Lady
# 147           5021      Pattern          Coloured
# 148           5021        Model             funky
# 149           5021        Theme           unusual
# 150           5021     Material               Pvc
# 151           5021         Size             Large
# 152           5021         Type           Handbag
# 153           5021         Type             Purse
# 154           5022        Brand      LAUREL BURCH
# 156           5022         Size            Medium
# 157           5022        Color              Blue
# 158           5022         Type          Shoulder
# 159           5022         Type              Tote
# 160           5022         Type           Handbag
# 161           5022  Fabric Type            Canvas
# 162           5022         Type               Bag
# 163           5023        Model            OSPREY
# 164           5023        Color             LIGHT

# %%
pred_df.to_csv('sub_df4_c.csv',index=False,encoding='utf-8')

# %%
pred_df.to_csv("sub_df4.tsv",sep="\t",index=False,header=False,quoting=csv.QUOTE_NONE,encoding='utf-8')

# %%
tree_df = pd.read_csv("df_tokenadj.csv")

# %%
tree_df = tree_df.drop(columns=['Token','BIO_tag'])

# %%
tree_df
# Out:
#        Record Number                                              Title  \
# 0                  1  LOUIS VUITTON M40096 Handbag Priscilla Multi-c...
# 1                  1  LOUIS VUITTON M40096 Handbag Priscilla Multi-c...
# 2                  1  LOUIS VUITTON M40096 Handbag Priscilla Multi-c...
# 3                  1  LOUIS VUITTON M40096 Handbag Priscilla Multi-c...
# 4                  1  LOUIS VUITTON M40096 Handbag Priscilla Multi-c...
# ...              ...                                                ...
# 48195           5000  Botkier Sasha Medium Duffel Bag Coral Leather ...
# 48196           5000  Botkier Sasha Medium Duffel Bag Coral Leather ...
# 48197           5000  Botkier Sasha Medium Duffel Bag Coral Leather ...
# 48198           5000  Botkier Sasha Medium Duffel Bag Coral Leather ...
# 48199           5000  Botkier Sasha Medium Duffel Bag Coral Leather ...
#
#           Tag  POS      Token_adj
# 0       Brand  NNP  LOUIS VUITTON
# 1         MPN  NNP         M40096
# 2        Type  NNP        Handbag
# 3       Model  NNP      Priscilla
# 4       Color  NNP    Multi-color
# ...       ...  ...            ...
# 48195  No Tag  NNP            Top
# 48196  No Tag  NNP        Closure
# 48197  No Tag  NNP         Retail
# 48198  No Tag    $              $
# 48199  No Tag   CD            595
#
# [48200 rows x 5 columns]

# %%
 from sklearn.ensemble import RandomForestClassifier

# %%
tree_w_emb = {}
tree_x = list(tree_df['Token_adj'])
tree_w_emb["UNK"]=0
idx=1
for w in tree_x:
    if not w in tree_w_emb.keys():
        tree_w_emb[w]=idx
        idx+=1

# %%
tree_tag_emb = {}
tree_y = list(tree_df['Tag'])
tree_tag_emb["UNK"]=0
idx=1
for w in tree_y:
    if not w in tree_tag_emb.keys():
        tree_tag_emb[w]=idx
        idx+=1

# %%
tree2word = {i: w for w, i in tree_w_emb.items()}
tree2tag = {i: w for w, i in tree_tag_emb.items()}

# %%
X = [tree_w_emb[x] for x in tree_x]
Y = [tree_tag_emb[y] for y in tree_y]

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (48200,)

# %%
X = X.reshape(1,-1)

# %%
X = X.T
X.shape
# Out:
# (48200, 1)

# %%
Y = np.array(Y)

# %%
Y.shape
# Out:
# (48200,)

# %%
clf = RandomForestClassifier()
clf.fit(X,Y)
# Out:
# RandomForestClassifier()

# %%
test_x = pred_df['Aspect Value']

# %%
test_x = list(test_x)
test_x
# Out:
# ['Kamen Rider',
#  'Gaim',
#  'Belt',
#  'HOBO',
#  'INTERNATIONAL',
#  "Women 's",
#  'LEATHER',
#  'Shoulder',
#  'Bag',
#  'CROSSBODY',
#  'Coach',
#  'Peyton',
#  'Brown',
#  'Tan',
#  'Signature C',
#  'Shoulder',
#  'Bag',
#  'Tote',
#  'Bag',
#  'MZ WALLACE',
#  'Metro',
#  'tote',
#  'gray',
#  'quilted',
#  'nylon',
#  'purse',
#  'Women',
#  'Sequins',
#  'Backpack',
#  'Travel',
#  'PU',
#  'Handbag',
#  'Rucksack',
#  'Shoulder',
#  'School',
#  'Bag',
#  'Thirty One',
#  'Large',
#  'Tote',
#  'FENDI',
#  'BAG',
#  'SHOULDER',
#  'BAG',
#  'ZUCCA',
#  'Nylon',
#  'Fashionic',
#  "Women 's",
#  'Shoulder',
#  'Cross-Body',
#  'Bag',
#  'Lightweight',
#  'Travel',
#  'Beach',
#  'Work',
#  'Scho',
#  'Dooney & Bourke',
#  'Black',
#  'Pebble',
#  'Leather',
#  'Tammy',
#  'Tote',
#  'Gucci',
#  'Womens',
#  'Indy',
#  'Shoulder',
#  'Handbag',
#  'Brown',
#  'Ostrich',
#  'Bamboo',
#  'Tassel',
#  'Purse',
#  'Evening',
#  'Bag',
#  'Brown',
#  'Stain',
#  'Silk',
#  'Black',
#  'Bead',
#  'Satin',
#  'Silk',
#  'Betseyville',
#  'Silver',
#  'Embossed',
#  'Star',
#  'Patent',
#  'Crossbody',
#  'Shoulder',
#  'Satchel',
#  'Bag',
#  'Carp',
#  'Canvas',
#  'Rucksack',
#  'Backpack',
#  'RK00014370',
#  'I',
#  'Love',
#  'Sandford',
#  'Somerset',
#  'Tote',
#  'Bag',
#  'Rutoto',
#  'ROOTOTE Rutoto',
#  'tote',
#  'bag',
#  'deli smaller',
#  'ladies',
#  'simple natur',
#  'Love',
#  'Moschino',
#  'Black',
#  'Canvas',
#  'Logo Embroidered',
#  'Shopping',
#  'Tote',
#  'stone and co',
#  'handbags',
#  'Ladies',
#  'Avon',
#  'Signature',
#  'Black',
#  'Bag',
#  'Ladies',
#  'Handbag',
#  'Womens',
#  'Transparent',
#  'Clear',
#  'Tote',
#  'Jelly',
#  'Handbag',
#  'Summer',
#  'Beach',
#  'Bag',
#  'Lady',
#  'Coloured',
#  'funky',
#  'unusual',
#  'Pvc',
#  'Large',
#  'Handbag',
#  'Purse',
#  'LAUREL BURCH',
#  'Medium',
#  'Blue',
#  'Shoulder',
#  'Tote',
#  'Handbag',
#  'Canvas',
#  'Bag',
#  'OSPREY',
#  'LIGHT',
#  'BROWN',
#  'LEATHER',
#  'MOC CROC',
#  'MEDIUM',
#  'SHOULDER',
#  'BAG',
#  'Women',
#  'Crossbody',
#  'Shoulder',
#  'Bags',
#  'Folded Front',
#  'Flap',
#  'AMELIE GALANTI',
#  'L',
#  'STERLING',
#  'Alligator',
#  'CROCODILE',
#  'BAG',
#  'Purse',
#  'HANDBAG',
#  'Pelle Studio',
#  'Wilsons',
#  'Brown',
#  'Leather',
#  'Patchwork',
#  'Hobo',
#  'Shoulder',
#  'Bag',
#  'Lino',
#  'Cotton',
#  'Mini',
#  'Tote',
#  'Bag',
#  'Leather',
#  'Womens',
#  'Tote',
#  'Large',
#  'Bag',
#  '15.6',
#  'Brown',
#  'biba',
#  'large',
#  'tote',
#  'bag',
#  'Gucci',
#  'Soho',
#  'Disco',
#  'GG',
#  'Logo',
#  'Black',
#  'Leather',
#  'Shoulder',
#  'Crossbody',
#  'Bag',
#  'Big',
#  'German',
#  'Luxury',
#  'LIEBESKIND',
#  'Shopper',
#  'Leather',
#  'Tote',
#  'punk',
#  'steampunk',
#  'black',
#  'Donna Sharp',
#  "Women 's",
#  'Elaina',
#  'Bag',
#  'Royal',
#  'Paisley',
#  'Boohoo',
#  'Womens',
#  'Quilt',
#  'Belt',
#  'Bag',
#  'Black',
#  'Shiny',
#  "women 's",
#  'clutch',
#  'handbag',
#  'purse',
#  'UNION BAY',
#  'CANVAS',
#  'PURSE',
#  'WALLET',
#  'PHONE',
#  'HOLDER',
#  'STRAP',
#  'Chanel',
#  'Quilted',
#  'Calfskin',
#  'Leather',
#  'Gold',
#  'Metal',
#  'Chain',
#  'Shoulder',
#  'Bag',
#  'Blue',
#  'Gucci',
#  'Bamboo',
#  'Hand',
#  'Nylon',
#  "It 's A",
#  'Physics',
#  'Graduate Thing You',
#  'Would',
#  "n't Understand",
#  'University',
#  'Tote',
#  'Bag',
#  'K-Carroll Ann',
#  'Square',
#  'Tote',
#  'Gray',
#  'Embroidered',
#  'Beaded',
#  'Evening',
#  'Bag',
#  'Tory Burch',
#  'Large',
#  'Tote',
#  'Patent',
#  'Navy',
#  'Lucky Brand',
#  'Shannon',
#  'White',
#  'Leather',
#  'Crossbody',
#  'Bag',
#  'Kipling',
#  'SUPERTABOO',
#  'Medium',
#  'Drawstring',
#  'Bag',
#  'Kate Spade',
#  'Black',
#  'Vinyl',
#  'Handbag',
#  'Purse',
#  'Crochet',
#  'Ivory',
#  'White',
#  'Lace',
#  'Brown',
#  'Faux',
#  'Leather',
#  'Shoulder',
#  'Bag',
#  'Purse',
#  'Satchel',
#  'Rock',
#  'Heavy Punk',
#  'Metal',
#  'Music',
#  'Guitar',
#  'Eco',
#  'Friendly',
#  'Tote',
#  'Bag',
#  'Shopping',
#  'TORY BURCH York',
#  'LARGE',
#  'CAMEL',
#  'BROWN',
#  'CROSS-GRAIN',
#  'LEATHER',
#  'TOTE',
#  'SHOULDER',
#  'BAG',
#  'CARRYALL',
#  'Louis Vuitton',
#  'Monogram',
#  'Musette Salsa',
#  'Long',
#  'Strap',
#  'Shoulder',
#  'Bag',
#  'LV',
#  'Radley',
#  'small',
#  'dog',
#  'charm',
#  'light',
#  'brown',
#  'Pierre Cardin',
#  'Logo',
#  'Boston',
#  'Bag',
#  'CALVIN KLEIN',
#  'HANDBAG',
#  'LYDC London',
#  'red',
#  'tassel',
#  'crossbody',
#  'bag',
#  'Handbag',
#  'Beaded',
#  'Hobo',
#  'Shoulder',
#  'Bag',
#  'Embroided',
#  'Tassel',
#  'Braided',
#  'Leather',
#  'Strap',
#  'rebecca minkoff',
#  'full',
#  'crossbody',
#  'CLARKS',
#  'LEATHER',
#  'CONKER',
#  'BROWN',
#  'SATCHEL',
#  'MESSENGER',
#  'SHOULDER',
#  'PURSE',
#  'restoration',
#  'beach',
#  'bag',
#  'FunnyKidsMiniEmojiFaceBackpack',
#  'School',
#  'Bookbag',
#  'Shoulder',
#  'Bag',
#  'Rucksack',
#  'LIEBESKIND',
#  'BERLIN',
#  'Chelsea',
#  'L',
#  'Black',
#  'Treviso',
#  'Dome',
#  'Satchel',
#  'Black',
#  'Brighton',
#  'Joy',
#  'Christmas',
#  'Canvas',
#  'Tote',
#  'Shoulder',
#  'Bag',
#  'Purse',
#  'Chanel',
#  'A66341',
#  'Pochette',
#  'Wallet',
#  'Bag',
#  'Diagonal Hanging',
#  'Chain',
#  'Shoulder',
#  'Coco',
#  'Cotton',
#  'Mandala',
#  'Unisex',
#  'Tote',
#  'Bag',
#  'Hippie',
#  'Bohemian',
#  'Festival',
#  'Boho',
#  'Beach',
#  'Bag',
#  'and Davis',
#  'Mesh',
#  'Cross',
#  'Body',
#  'Purse',
#  'Ivory',
#  'Beige',
#  'Republic',
#  'Brown',
#  'O-Ring',
#  'Flap',
#  'Tab',
#  'Shoulder',
#  'Bag',
#  'Wristlet',
#  'Purse',
#  'Coach',
#  'Signature',
#  'Gold',
#  'Tote',
#  'hand',
#  'woven',
#  'bag',
#  'rattan',
#  'straw',
#  'Home',
#  'Bag',
#  'Purse',
#  'Organizer',
#  'Felt',
#  'Insert',
#  'Bag',
#  'Makeup',
#  'Organizer',
#  'Inner',
#  'Michelle',
#  'Obama Magazine',
#  '3-Compartment',
#  'Tote',
#  'Handbag',
#  'Wallet',
#  'Coach',
#  'Legacy',
#  'Cognac',
#  'Brown',
#  'Leather',
#  'Chelsea',
#  'Satchel',
#  'Carryall',
#  'Michael Kors',
#  'Snake',
#  'Leather',
#  'Crossbody',
#  'Clutch',
#  'Bag',
#  'Louis Vuitton',
#  'Monogram',
#  'Noe',
#  'Shoulder',
#  'Bag',
#  'M42224',
#  'Brown',
#  'Previously',
#  'Ladies',
#  'Purple',
#  'Jaeger',
#  'bag',
#  'baggallini',
#  'crossbody',
#  'Coin',
#  'Purse',
#  'kate spade',
#  'purple',
#  'patent',
#  'leather',
#  'small',
#  'hobo',
#  'bag',
#  'NIGHTS AT FREDDYS',
#  'LETS EAT',
#  'MESSENGER',
#  'REPORTER',
#  'BAG',
#  'Vera Bradley',
#  'SCOTTIE DOGS',
#  'Large',
#  'Hipster',
#  'Kate Spade',
#  'Burgundy',
#  'Leather',
#  'Shoulder',
#  'Bag',
#  'Purse',
#  'Wilsons',
#  'Small',
#  'Leather',
#  'Black',
#  'Adjustable',
#  'Backpack',
#  'Bag',
#  'Travel',
#  'Mini',
#  'Vacation 90s',
#  'Y2K',
#  'Linea',
#  'Pelle',
#  'Women',
#  'Black',
#  'Leather',
#  'Satchel',
#  'Black',
#  'Leather',
#  'Fossil',
#  'Crossbody',
#  'Bag',
#  'Purse',
#  'Quote',
#  'By',
#  'Sylvia',
#  'Plath',
#  'Canvas',
#  'Clutch',
#  'Bag',
#  'Accessory',
#  'Case',
#  'CL00007552',
#  'Louis Vuitton',
#  'Shoulder',
#  'Bag',
#  'Pochette',
#  'Cite',
#  'M51183',
#  'Browns',
#  'Monogram',
#  'Coldwater Creek',
#  'Leather',
#  'Crossbody',
#  'Ruffled',
#  'Purse',
#  'Organizer',
#  'Bag',
#  'Herocca Lesportsac',
#  'Hawaii Dreaming',
#  'Classic',
#  'Hobo',
#  'Crossbody',
#  'louis vuitton',
#  'mini',
#  'speedy',
#  'Dooney & Bourke',
#  'Black',
#  'Leather',
#  'Purse',
#  'Ladies',
#  'Guess',
#  'Bag',
#  'michael Kors',
#  'handbag',
#  'BORSE',
#  'PELLE',
#  'Italy',
#  'Brown',
#  'Leather',
#  'Shoulder',
#  'Boho',
#  'Saddle',
#  'Hobo',
#  'Tooled',
#  'Bag',
#  'Louis Vuitton',
#  'Pochette',
#  'Gange',
#  'Monogram',
#  'Canvas',
#  'Waist',
#  'Bag',
#  'M51870',
#  'Hermes',
#  'Baby',
#  'Boreido Mm',
#  'Logo',
#  'Cosmetics',
#  'Make',
#  'Up',
#  'Pouch',
#  'Case',
#  'Bag',
#  'Elephant Mandala',
#  "Women 's",
#  'Handcrafted',
#  'Boots',
#  'verry berry',
#  'Kipling',
#  "Women 's",
#  'Syro',
#  'Shoulder',
#  'Bag',
#  'Berry',
#  'Longchamp',
#  'Le Pliage',
#  'Long Handle',
#  'Large',
#  'Tote',
#  'BLACK',
#  'Women',
#  'Glitter Sequins Dazzling',
#  'Evening',
#  'Party',
#  'Handbag',
#  'Bag',
#  'Clutch',
#  'Purse',
#  'Radley',
#  'Signature',
#  'Bag',
#  'home',
#  'GUCCI',
#  'GG Plus',
#  'Web',
#  'Stripe',
#  'Clutch',
#  'Pouch',
#  'Bag',
#  'Brown',
#  'PVC',
#  'Italy',
#  '#SS 911',
#  'Ladies',
#  'Orange',
#  'Cream',
#  'Bag',
#  'Burberry',
#  'Tote',
#  'handbag',
#  'Christian Dior',
#  'Trotter',
#  'Shoulder',
#  'Bag',
#  'Logogram',
#  'Red',
#  'Womens',
#  'bag',
#  'Leather',
#  'Handbags',
#  'Shoulder',
#  'Bags',
#  'Tote',
#  'Female',
#  'Purse',
#  'GUCCI',
#  'Silk',
#  'Handbag',
#  'Shoulder',
#  'Evening',
#  'Bag',
#  'Clutch',
#  'Wallet',
#  'Crossbody',
#  'Black',
#  'Red',
#  'Womens',
#  'BROWN',
#  'ITALIAN',
#  'LEATHER',
#  'HAND',
#  'SHOULDER',
#  'BAG',
#  'FURLA',
#  'SLOUCHY',
#  'HOBO',
#  'Lucky Brand',
#  'Leather',
#  'Boho',
#  'Crossbody',
#  'Purse',
#  'Flap',
#  'GZS Jimmy Choo',
#  'Leather',
#  'Tote',
#  'Bag',
#  'Black',
#  'EMPORIO ARMANI',
#  "Woman 's",
#  'faux',
#  'leather',
#  'shopper',
#  'clutch',
#  'Fendi',
#  'Roll',
#  'Tote',
#  'Zucca',
#  'Coated',
#  'Canvas',
#  'Large',
#  'Ladies',
#  'Gucci',
#  'Bag',
#  'Chain',
#  'Handle',
#  'Hi',
#  'Hi',
#  'Bag',
#  'Small',
#  'Blue',
#  'Pink',
#  '10',
#  '16 X',
#  '6',
#  'CM',
#  'Mauna Loa',
#  'Bag',
#  'of',
#  'Purses',
#  'Bags',
#  'Totes',
#  'Bags',
#  'Ladies',
#  'Travel',
#  'Messenger',
#  'Bag',
#  'Handbag',
#  'Summer',
#  'Ladies',
#  'Bucket',
#  'Bag',
#  'ShR2H3',
#  'backpack',
#  'leather',
#  'bag',
#  'Kate Spade NY',
#  'Staci Cameron',
#  'Satchel',
#  'Shoulder',
#  'Tote',
#  'Bag',
#  'Medium',
#  'Black',
#  'Vera Bradley',
#  'Large',
#  'Travel',
#  'Duffel',
#  'Bag',
#  'Red',
#  'Bandana',
#  'Ted Baker',
#  'Polyvinyl',
#  'Tote',
#  'Bag',
#  'Bow',
#  'Hobo',
#  'leather',
#  'bag',
#  'brown',
#  'Lisanne',
#  'Tote',
#  'Wallet',
#  'MICHAEL KORS',
#  'Signature MK',
#  'METALLIC',
#  'BRONZE',
#  'Bag',
#  'Marni',
#  'Women',
#  'Brown',
#  'Satchel',
#  'Women',
#  'NEW',
#  'YNOT',
#  'Trolley',
#  'Blue',
#  'navy',
#  'Trolley',
#  'TSA',
#  'lock',
#  'Unisex',
#  'L11003PE19-BLUE',
#  'COUNTRY',
#  'ROAD',
#  'Australia',
#  'Tote',
#  'Shoulder',
#  'Bag',
#  'Chala',
#  'Hobo',
#  'handbag',
#  'detachable',
#  'Coin',
#  'Purse',
#  'Rainbow Owl',
#  'HERMES',
#  'Fourre Tout',
#  'MM',
#  'Handbag',
#  'Navy',
#  'Brown',
#  'Brown',
#  'Bag',
#  '1970s',
#  'floral',
#  'bag',
#  'plastic',
#  'handles bird',
#  'flowers cottagecore',
#  'Prada',
#  'Pushlock',
#  'Messenger',
#  'Bag',
#  'Saffiano',
#  'Leather',
#  'Mini',
#  'Kate Spade',
#  'York x',
#  'Minnie Mouse',
#  'Mini',
#  'Crossbody',
#  'Leather',
#  'Purse',
#  'Beaded',
#  'Evening',
#  'Handbag',
#  'Cocktail',
#  'Party',
#  'Peaky Blinders',
#  'Flapper',
#  'Gold',
#  'Celine',
#  'Boston',
#  'Bag',
#  "Women 'S",
#  'No. 135',
#  "Women 's",
#  'Two',
#  'Zip',
#  'Pockets',
#  'Faux',
#  'Leather',
#  'Crossbody',
#  'Clutch',
#  'Black',
#  'Bags',
#  'Shoulder',
#  'Bags',
#  'Purse',
#  'Messenger',
#  'Satchel',
#  'Handle',
#  'Bags',
#  'Crossbody',
#  'Women',
#  'Gucci',
#  'Gutchishima',
#  'handbag',
#  'leather',
#  'flower',
#  'Handbags',
#  'Bucket',
#  'Bag',
#  'Embroidery',
#  'Chain',
#  'Bag',
#  'Ladies',
#  'navy',
#  'shoulder',
#  'handbag',
#  'fringe',
#  'adjustable',
#  'strap',
#  'Gucci',
#  'Borsa',
#  'Padlock',
#  'Gucci',
#  'Signature',
#  'Top Handle',
#  'Leather',
#  'Bag',
#  'Red',
#  'Longchamp',
#  'Le Pliage',
#  'Modele Depose',
#  'Large',
#  'Tote',
#  'Shopper',
#  'Bag',
#  'Gucci',
#  'Shoulder',
#  'bag',
#  'G logos',
#  'Beige',
#  'Black',
#  'Woman',
#  'U3748',
#  'black',
#  'bag',
#  'gold',
#  'metal',
#  'handles',
#  'strap',
#  'Mandala',
#  'Handbag',
#  'Indian',
#  'Hippie',
#  'Tote',
#  'Bag',
#  'Shoulder',
#  'Cotton',
#  'Women',
#  'Satchel',
#  'Lady',
#  'Purse',
#  'Happy',
#  'Punk Cat',
#  'Tote',
#  'Shopping',
#  'Bag',
#  'BG00052137',
#  'Novelty',
#  '5-Year',
#  'Warranty',
#  'Ace Jean',
#  'Business',
#  'Tote',
#  'Ace.Gene',
#  'Slibrite Suribrite',
#  'Bag',
#  'Crossbody',
#  'Loungefly',
#  'Brown',
#  'Owl',
#  'shaped',
#  'cross',
#  'body',
#  'handbag',
#  'LOVE',
#  'PINK',
#  'Fanny',
#  'Pack',
#  'Blue',
#  'small',
#  'Crocodile',
#  'Leather',
#  'Messenger',
#  'Bag',
#  'Women',
#  'Retro',
#  'Purse',
#  'Casual',
#  'Shoulder',
#  'Handbag',
#  'COACH',
#  'SIGNATURE STRIPE',
#  'KHAKI',
#  'HOT PINK',
#  'SWINGPACK',
#  'CROSSBODY',
#  'BAG',
#  'PURSE',
#  'Louis Vuitton',
#  'Palm',
#  'Springs',
#  'Backpack',
#  'MM',
#  'M41561',
#  'Tote',
#  'Handbag',
#  'Cotton',
#  'Shopping',
#  'Bag',
#  'Seascape',
#  'Beach',
#  'LONGCHAMP',
#  'Shop It',
#  'Dark',
#  'Green',
#  'Suede',
#  'Leather',
#  'Tote',
#  'Bag',
#  'Gucci',
#  'Pouch',
#  'Beige',
#  'Woman',
#  'Y4952',
#  'Michael Kors',
#  'Riley',
#  'Large',
#  'Pebbled',
#  'Leather',
#  'Top Zip',
#  ...]

# %%
test_x_enc = [tree_w_emb[x] if x in tree_w_emb.keys() else 0 for x in test_x ]

# %%
test_x_enc = np.asarray(test_x_enc).reshape(1,-1)
test_x_enc = test_x_enc.T

# %%
test_x_enc.shape
# Out:
# (172244, 1)

# %%
test_y = clf.predict(test_x_enc)

# %%
ty = list(test_y)

# %%
tree2tag[0]
# Out:
# 'UNK'

# %%
tree_tags = [tree2tag[y] for y in ty]

# %%
tree_tags
# Out:
# ['Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Department',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Model',
#  'Color',
#  'Color',
#  'Pattern',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Color',
#  'Features',
#  'Material',
#  'Type',
#  'Department',
#  'Accents',
#  'Type',
#  'Occasion',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Size',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Pattern',
#  'Material',
#  'Brand',
#  'Department',
#  'Type',
#  'Type',
#  'Type',
#  'Features',
#  'Occasion',
#  'Occasion',
#  'Occasion',
#  'Brand',
#  'Brand',
#  'Color',
#  'Pattern',
#  'Material',
#  'Brand',
#  'Type',
#  'Brand',
#  'Department',
#  'Product Line',
#  'Type',
#  'Type',
#  'Color',
#  'Material',
#  'Product Line',
#  'Accents',
#  'Type',
#  'Occasion',
#  'Type',
#  'Color',
#  'Brand',
#  'Material',
#  'Color',
#  'Handle/Strap Material',
#  'Material',
#  'Material',
#  'Brand',
#  'Color',
#  'Accents',
#  'No Tag',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'Brand',
#  'No Tag',
#  'Model',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Department',
#  'Brand',
#  'Model',
#  'Brand',
#  'Color',
#  'Fabric Type',
#  'Accents',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Department',
#  'Brand',
#  'Pattern',
#  'Color',
#  'Type',
#  'Department',
#  'Type',
#  'Department',
#  'Accents',
#  'Color',
#  'Type',
#  'Material',
#  'Type',
#  'Season',
#  'Occasion',
#  'Type',
#  'Department',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Material',
#  'Size',
#  'Type',
#  'Type',
#  'Brand',
#  'Size',
#  'Color',
#  'Type',
#  'Type',
#  'Type',
#  'Fabric Type',
#  'Type',
#  'Brand',
#  'Color',
#  'Color',
#  'Material',
#  'Brand',
#  'Size',
#  'Type',
#  'Type',
#  'Department',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Brand',
#  'Size',
#  'Brand',
#  'Material',
#  'Pattern',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Color',
#  'Material',
#  'Pattern',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Material',
#  'Size',
#  'Type',
#  'Type',
#  'Material',
#  'Department',
#  'Type',
#  'Size',
#  'Type',
#  'Brand',
#  'Color',
#  'Brand',
#  'Size',
#  'Type',
#  'Type',
#  'Brand',
#  'Model',
#  'Model',
#  'Brand',
#  'Accents',
#  'Color',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Size',
#  'Brand',
#  'Theme',
#  'Brand',
#  'Type',
#  'Material',
#  'Type',
#  'Brand',
#  'Brand',
#  'Color',
#  'Brand',
#  'Department',
#  'Brand',
#  'Type',
#  'Theme',
#  'Pattern',
#  'Brand',
#  'Department',
#  'Features',
#  'Type',
#  'Type',
#  'Color',
#  'Accents',
#  'Department',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'Obscure',
#  'Features',
#  'Handle Style',
#  'Brand',
#  'Features',
#  'Material',
#  'Material',
#  'Color',
#  'Hardware Material',
#  'Handle/Strap Material',
#  'Type',
#  'Type',
#  'Color',
#  'Brand',
#  'Product Line',
#  'Type',
#  'Material',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Color',
#  'Accents',
#  'Accents',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Size',
#  'Type',
#  'Material',
#  'Color',
#  'Brand',
#  'Brand',
#  'Color',
#  'Material',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Size',
#  'Closure',
#  'Type',
#  'Brand',
#  'Color',
#  'Material',
#  'Type',
#  'Type',
#  'Fabric Type',
#  'Color',
#  'Color',
#  'Fabric Type',
#  'Color',
#  'Material',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Hardware Material',
#  'Brand',
#  'Pattern',
#  'Features',
#  'No Tag',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Size',
#  'Color',
#  'Color',
#  'Brand',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Model',
#  'No Tag',
#  'Handle Style',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Size',
#  'Brand',
#  'Accents',
#  'Color',
#  'Color',
#  'Brand',
#  'Accents',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Brand',
#  'Color',
#  'Accents',
#  'Type',
#  'Type',
#  'Type',
#  'Accents',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Accents',
#  'Fabric Type',
#  'Material',
#  'Handle Style',
#  'Brand',
#  'Brand',
#  'Type',
#  'Brand',
#  'Material',
#  'Brand',
#  'Color',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Occasion',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Country/Region of Manufacture',
#  'Style',
#  'Size',
#  'Color',
#  'Brand',
#  'Style',
#  'Type',
#  'Color',
#  'Brand',
#  'Model',
#  'No Tag',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Product Line',
#  'Type',
#  'Type',
#  'Brand',
#  'Handle/Strap Material',
#  'Type',
#  'Product Line',
#  'Material',
#  'Pattern',
#  'Department',
#  'Type',
#  'Type',
#  'Style',
#  'Style',
#  'Occasion',
#  'Style',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'Type',
#  'Color',
#  'Color',
#  'Brand',
#  'Color',
#  'Brand',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Handle Style',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Color',
#  'Type',
#  'Type',
#  'Fabric Type',
#  'Type',
#  'Material',
#  'Material',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Material',
#  'No Tag',
#  'Type',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Model',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Product Line',
#  'Color',
#  'Color',
#  'Material',
#  'Style',
#  'Type',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Model',
#  'Type',
#  'Type',
#  'MPN',
#  'Color',
#  'Brand',
#  'Department',
#  'Color',
#  'Brand',
#  'Type',
#  'Brand',
#  'Type',
#  'No Tag',
#  'Type',
#  'Brand',
#  'Color',
#  'Material',
#  'Material',
#  'Size',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Brand',
#  'Type',
#  'Brand',
#  'Brand',
#  'Size',
#  'Model',
#  'Brand',
#  'Color',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Size',
#  'Material',
#  'Color',
#  'Features',
#  'Type',
#  'Type',
#  'Occasion',
#  'Size',
#  'Brand',
#  'Brand',
#  'Model',
#  'Brand',
#  'Department',
#  'Color',
#  'Material',
#  'Type',
#  'Color',
#  'Material',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'No Tag',
#  'Brand',
#  'Brand',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'Obscure',
#  'Obscure',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Product Line',
#  'Brand',
#  'MPN',
#  'Color',
#  'Pattern',
#  'Brand',
#  'Material',
#  'Type',
#  'Accents',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Model',
#  'Type',
#  'Type',
#  'Brand',
#  'Size',
#  'No Tag',
#  'Brand',
#  'Color',
#  'Material',
#  'Type',
#  'Department',
#  'Brand',
#  'Type',
#  'Brand',
#  'Type',
#  'Brand',
#  'Brand',
#  'Country/Region of Manufacture',
#  'Color',
#  'Material',
#  'Type',
#  'Style',
#  'Type',
#  'Type',
#  'Accents',
#  'Type',
#  'Brand',
#  'Product Line',
#  'Model',
#  'Pattern',
#  'Fabric Type',
#  'Type',
#  'Type',
#  'MPN',
#  'Brand',
#  'No Tag',
#  'Brand',
#  'Accents',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Obscure',
#  'Type',
#  'Brand',
#  'Department',
#  'Features',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Department',
#  'Brand',
#  'Type',
#  'Type',
#  'Color',
#  'Brand',
#  'Model',
#  'Handle Style',
#  'Size',
#  'Type',
#  'Color',
#  'Department',
#  'Brand',
#  'Occasion',
#  'Occasion',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Type',
#  'Brand',
#  'Brand',
#  'Product Line',
#  'Product Line',
#  'Pattern',
#  'Type',
#  'Type',
#  'Type',
#  'Color',
#  'Material',
#  'Country/Region of Manufacture',
#  'Brand',
#  'Department',
#  'Color',
#  'Color',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Model',
#  'Type',
#  'Type',
#  'Brand',
#  'Color',
#  'Department',
#  'Type',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Department',
#  'Type',
#  'Brand',
#  'Material',
#  'Type',
#  'Type',
#  'Occasion',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Color',
#  'Color',
#  'Department',
#  'Color',
#  'Country/Region of Manufacture',
#  'Material',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Style',
#  'Type',
#  'Brand',
#  'Material',
#  'Style',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Material',
#  'Type',
#  'Type',
#  'Color',
#  'Brand',
#  'Department',
#  'Brand',
#  'Material',
#  'Type',
#  'Type',
#  'Brand',
#  'No Tag',
#  'Type',
#  'Pattern',
#  'Fabric Type',
#  'Fabric Type',
#  'Size',
#  'Department',
#  'Brand',
#  'Type',
#  'Handle/Strap Material',
#  'Handle Style',
#  'Brand',
#  'Brand',
#  'Type',
#  'Size',
#  'Color',
#  'Color',
#  'No Tag',
#  'Brand',
#  'Obscure',
#  'Brand',
#  'Brand',
#  'Type',
#  'No Tag',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Department',
#  'Occasion',
#  'Type',
#  'Type',
#  'Type',
#  'Season',
#  'Department',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Material',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Size',
#  'Color',
#  'Brand',
#  'Size',
#  'Occasion',
#  'Type',
#  'Type',
#  'Color',
#  'Pattern',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Accents',
#  'Type',
#  'Material',
#  'Type',
#  'Color',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Pattern',
#  'Color',
#  'Color',
#  'Type',
#  'Brand',
#  'Department',
#  'Color',
#  'Type',
#  'Department',
#  'No Tag',
#  'Brand',
#  'Obscure',
#  'Color',
#  'Color',
#  'Obscure',
#  'Brand',
#  'Brand',
#  'Department',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Features',
#  'No Tag',
#  'Type',
#  'Brand',
#  'Brand',
#  'Product Line',
#  'Model',
#  'Type',
#  'Color',
#  'Color',
#  'Color',
#  'Type',
#  'Theme',
#  'Pattern',
#  'Type',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Material',
#  'Material',
#  'Size',
#  'Brand',
#  'Brand',
#  'Character',
#  'Size',
#  'Type',
#  'Material',
#  'Type',
#  'Accents',
#  'Occasion',
#  'Type',
#  'Style',
#  'Occasion',
#  'Brand',
#  'Brand',
#  'Color',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Department',
#  'No Tag',
#  'Closure',
#  'Features',
#  'Material',
#  'Material',
#  'Type',
#  'Type',
#  'Color',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Type',
#  'Handle Style',
#  'Type',
#  'Type',
#  'Department',
#  'Brand',
#  'Brand',
#  'Type',
#  'Material',
#  'Pattern',
#  'Type',
#  'Type',
#  'Type',
#  'Accents',
#  'Handle/Strap Material',
#  'Type',
#  'Department',
#  'Color',
#  'Type',
#  'Type',
#  'Accents',
#  'Features',
#  'Handle Style',
#  'Brand',
#  'Material',
#  'Closure',
#  'Brand',
#  'Pattern',
#  'Handle Style',
#  'Material',
#  'Type',
#  'Color',
#  'Brand',
#  'Model',
#  'Brand',
#  'Size',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Type',
#  'Accents',
#  'Color',
#  'Color',
#  'Department',
#  'Brand',
#  'Color',
#  'Type',
#  'Color',
#  'Hardware Material',
#  'Handle Style',
#  'Handle Style',
#  'Pattern',
#  'Type',
#  'Theme',
#  'Style',
#  'Type',
#  'Type',
#  'Type',
#  'Material',
#  'Department',
#  'Type',
#  'Department',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Theme',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Occasion',
#  'Type',
#  'Brand',
#  'Brand',
#  'Type',
#  'Type',
#  'Brand',
#  'Color',
#  'Pattern',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Type',
#  'Brand',
#  'Color',
#  'Type',
#  'Type',
#  'Color',
#  'Size',
#  'Pattern',
#  'Material',
#  'Type',
#  'Type',
#  'Department',
#  'Style',
#  'Type',
#  'Occasion',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Color',
#  'Color',
#  'Style',
#  'Type',
#  'Type',
#  'Type',
#  'Brand',
#  'Brand',
#  'Brand',
#  'Type',
#  'Model',
#  'Brand',
#  'Type',
#  'Type',
#  'Material',
#  'Type',
#  'Type',
#  'Brand',
#  'Occasion',
#  'Brand',
#  'Brand',
#  'Color',
#  'Color',
#  'Material',
#  'Material',
#  'Type',
#  'Type',
#  'Brand',
#  'Type',
#  'Color',
#  'Department',
#  'Brand',
#  'Brand',
#  'Model',
#  'Size',
#  'Pattern',
#  'Material',
#  'Closure',
#  ...]

# %%
pred_df['TreeTags']=tree_tags

# %%
pred_df[pred_df['Aspect Name']!=pred_df['TreeTags']]
# Out:
#         Record Number Aspect Name Aspect Value TreeTags
# 2                5001       Model         Gaim    Brand
# 24               5004       Model        Metro    Brand
# 60               5008    Occasion         Scho    Brand
# 67               5009       Model        Tammy    Brand
# 82               5011       Color        Stain    Brand
# ...               ...         ...          ...      ...
# 193030          29997       Model   Blackheath    Brand
# 193034          29998       Model       Piatto    Brand
# 193041          29999       Model        Jaald    Brand
# 193054          30000    Features      QUILTED  Accents
# 193055          30000       Model      BLAKELY    Brand
#
# [30225 rows x 4 columns]

# %%
len(pred_df)
# Out:
# 172244
